# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# merge 12 months of sales data into single csv file

# %%
path = "./Sales_Data"
files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

all_months_data = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(path+"/"+file)
    all_months_data = pd.concat([all_months_data, current_data])
    
all_months_data.to_csv("all_data_copy.csv", index=False)
all_data = pd.read_csv("all_data_copy.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
display(nan_df.head())

all_data = all_data.dropna(how='all')
all_data.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
sales_data = sales_data.dropna(how= 'all')

# %%
#find or and delete it
all_data = all_data[all_data['Order Date'].str[0:2]!='Or']

# %% [markdown]
# #### What was the month where sales were great

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
all_data['Sales'] = all_data['Quantity Ordered'].astype('int') * all_data['Price Each'].astype('float')

# %%
all_data.groupby(['Month']).sum()
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\2666040485.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_data.groupby(['Month']).sum()
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
months = range(1,13)
plt.bar(months,all_data.groupby(['Month']).sum()['Sales'])

plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\2451079701.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.bar(months,all_data.groupby(['Month']).sum()['Sales'])

# %% [markdown]
# #### What city had the highest number of sales

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month   Sales
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001      4   23.90
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215      4   99.99
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001      4   11.99
# ...                ...                                      ...    ...     ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001      9    8.97
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016      9  700.00
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016      9  700.00
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016      9  379.99
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016      9   11.95
#
# [185950 rows x 8 columns]

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                         city               City
# 0       [ Dallas,  TX 75001]       Dallas  (TX)
# 2       [ Boston,  MA 02215]       Boston  (MA)
# 3  [ Los Angeles,  CA 90001]  Los Angeles  (CA)
# 4  [ Los Angeles,  CA 90001]  Los Angeles  (CA)
# 5  [ Los Angeles,  CA 90001]  Los Angeles  (CA)

# %%
result = all_data.groupby(['City']).sum()
result
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\3455920883.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result = all_data.groupby(['City']).sum()
#                      Quantity Ordered  Price Each   Month       Sales
# City
# Atlanta  (GA)                   16602  2779908.20  104794  2795498.58
# Austin  (TX)                    11153  1809873.61   69829  1819581.75
# Boston  (MA)                    22528  3637409.77  141112  3661642.01
# Dallas  (TX)                    16730  2752627.82  104620  2767975.40
# Los Angeles  (CA)               33289  5421435.23  208325  5452570.80
# New York City  (NY)             27932  4635370.83  175741  4664317.43
# Portland  (ME)                   2750   447189.25   17144   449758.27
# Portland  (OR)                  11303  1860558.22   70621  1870732.34
# San Francisco  (CA)             50239  8211461.74  315520  8262203.91
# Seattle  (WA)                   16553  2733296.01  104941  2747755.48

# %%
cities = [city for city, df in all_data.groupby('City')]
cities
# Out:
# ['Atlanta  (GA)',
#  'Austin  (TX)',
#  'Boston  (MA)',
#  'Dallas  (TX)',
#  'Los Angeles  (CA)',
#  'New York City  (NY)',
#  'Portland  (ME)',
#  'Portland  (OR)',
#  'San Francisco  (CA)',
#  'Seattle  (WA)']

# %%
plt.bar(cities,all_data.groupby(['City']).sum()['Sales'])

plt.xticks(cities,rotation='vertical')
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\851632050.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.bar(cities,all_data.groupby(['City']).sum()['Sales'])

# %% [markdown]
# #### What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
# Add hour column
all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour
all_data['Minute'] = pd.to_datetime(all_data['Order Date']).dt.minute
all_data['Count'] = 1

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001      4
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215      4
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001      4
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001      4
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001      4
# ...                ...                                      ...    ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001      9
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016      9
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016      9
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016      9
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016      9
#
#          Sales                         city                 City  Hour  \
# 0        23.90         [ Dallas,  TX 75001]         Dallas  (TX)     8
# 2        99.99         [ Boston,  MA 02215]         Boston  (MA)    22
# 3       600.00    [ Los Angeles,  CA 90001]    Los Angeles  (CA)    14
# 4        11.99    [ Los Angeles,  CA 90001]    Los Angeles  (CA)    14
# 5        11.99    [ Los Angeles,  CA 90001]    Los Angeles  (CA)     9
# ...        ...                          ...                  ...   ...
# 186845    8.97    [ Los Angeles,  CA 90001]    Los Angeles  (CA)    20
# 186846  700.00  [ San Francisco,  CA 94016]  San Francisco  (CA)    16
# 186847  700.00  [ San Francisco,  CA 94016]  San Francisco  (CA)     7
# 186848  379.99  [ San Francisco,  CA 94016]  San Francisco  (CA)    17
# 186849   11.95  [ San Francisco,  CA 94016]  San Francisco  (CA)     0
#
#         Minute  Count
# 0           46      1
# 2           30      1
# 3           38      1
# 4           38      1
# 5           27      1
# ...        ...    ...
# 186845      56      1
# 186846       0      1
# 186847      39      1
# 186848      30      1
# 186849      18      1
#
# [185950 rows x 13 columns]

# %%
all_data.groupby('Hour').sum()
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\2700126675.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_data.groupby('Hour').sum()
#       Quantity Ordered  Price Each  Month       Sales  Minute  Count
# Hour
# 0                 4428   709296.70  27554   713721.27  103596   3910
# 1                 2619   458490.00  16657   460866.88   61807   2350
# 2                 1398   233833.64   8507   234851.44   32508   1243
# 3                  928   144726.42   5904   145757.89   23044    831
# 4                  937   162058.18   6148   162661.01   26876    854
# 5                 1493   229621.21   9301   230679.82   42877   1321
# 6                 2810   445000.11  17539   448113.00   80343   2482
# 7                 4556   740568.11  28850   744854.12  127447   4011
# 8                 7002  1185970.62  43626  1192348.97  198135   6256
# 9                 9816  1628498.49  60981  1639030.58  268253   8748
# 10               12308  1932665.62  76928  1944286.77  331941  10944
# 11               14005  2288855.18  87654  2300610.24  368952  12411
# 12               14202  2299876.68  89161  2316821.34  368679  12587
# 13               13685  2139743.86  85808  2155389.80  351045  12129
# 14               12362  2072194.77  77836  2083672.73  322563  10984
# 15               11391  1931174.99  72060  1941549.60  299893  10175
# 16               11662  1892454.54  72939  1904601.31  310132  10384
# 17               12229  2116777.02  77454  2129361.61  323428  10899
# 18               13802  2207696.93  86421  2219348.30  371688  12280
# 19               14470  2398588.31  91389  2412938.54  381042  12905
# 20               13768  2268185.16  86375  2281716.24  354086  12228
# 21               12244  2030763.83  77103  2042000.86  312062  10921
# 22                9899  1599464.44  62088  1607549.21  248503   8822
# 23                7065  1172625.87  44364  1179304.44  173159   6275

# %%
keys = range(0,24)

plt.plot(keys, all_data.groupby(['Hour']).count()['Count'])
plt.xticks(keys)
plt.grid()
plt.show()

# %% [markdown]
# ### What products are often sold togather

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

# %%
all_data1 = all_data[all_data['Order Date'] == '2019-04-19 08:46:00']

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\701253533.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 18       176574                Google Phone                 1      600.00
# 19       176574        USB-C Charging Cable                 1       11.95
# 30       176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186792   259303       AA Batteries (4-pack)                 1        3.84
# 186803   259314            Wired Headphones                 1       11.99
# 186804   259314      AAA Batteries (4-pack)                 2        2.99
# 186841   259350                Google Phone                 1      600.00
# 186842   259350        USB-C Charging Cable                 1       11.95
#
#                 Order Date                       Purchase Address  Month  \
# 3      2019-04-12 14:38:00   669 Spruce St, Los Angeles, CA 90001      4
# 4      2019-04-12 14:38:00   669 Spruce St, Los Angeles, CA 90001      4
# 18     2019-04-03 19:42:00      20 Hill St, Los Angeles, CA 90001      4
# 19     2019-04-03 19:42:00      20 Hill St, Los Angeles, CA 90001      4
# 30     2019-04-07 11:31:00      823 Highland St, Boston, MA 02215      4
# ...                    ...                                    ...    ...
# 186792 2019-09-20 20:18:00          106 7th St, Atlanta, GA 30301      9
# 186803 2019-09-16 00:25:00     241 Highland St, Atlanta, GA 30301      9
# 186804 2019-09-16 00:25:00     241 Highland St, Atlanta, GA 30301      9
# 186841 2019-09-30 13:49:00  519 Maple St, San Francisco, CA 94016      9
# 186842 2019-09-30 13:49:00  519 Maple St, San Francisco, CA 94016      9
#
#          Sales                         city                 City  Hour  \
# 3       600.00    [ Los Angeles,  CA 90001]    Los Angeles  (CA)    14
# 4        11.99    [ Los Angeles,  CA 90001]    Los Angeles  (CA)    14
# 18      600.00    [ Los Angeles,  CA 90001]    Los Angeles  (CA)    19
# 19       11.95    [ Los Angeles,  CA 90001]    Los Angeles  (CA)    19
# 30       99.99         [ Boston,  MA 02215]         Boston  (MA)    11
# ...        ...                          ...                  ...   ...
# 186792    3.84        [ Atlanta,  GA 30301]        Atlanta  (GA)    20
# 186803   11.99        [ Atlanta,  GA 30301]        Atlanta  (GA)     0
# 186804    5.98        [ Atlanta,  GA 30301]        Atlanta  (GA)     0
# 186841  600.00  [ San Francisco,  CA 94016]  San Francisco  (CA)    13
# 186842   11.95  [ San Francisco,  CA 94016]  San Francisco  (CA)    13
#
#         Minute  Count                                            Grouped
# 3           38      1                      Google Phone,Wired Headphones
# 4           38      1                      Google Phone,Wired Headphones
# 18          42      1                  Google Phone,USB-C Charging Cable
# 19          42      1                  Google Phone,USB-C Charging Cable
# 30          31      1  Bose SoundSport Headphones,Bose SoundSport Hea...
# ...        ...    ...                                                ...
# 186792      18      1       34in Ultrawide Monitor,AA Batteries (4-pack)
# 186803      25      1            Wired Headphones,AAA Batteries (4-pack)
# 186804      25      1            Wired Headphones,AAA Batteries (4-pack)
# 186841      49      1                  Google Phone,USB-C Charging Cable
# 186842      49      1                  Google Phone,USB-C Charging Cable
#
# [14649 rows x 14 columns]

# %%
df1b = df.groupby('Grouped').sum()
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\3367236483.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1b = df.groupby('Grouped').sum()

# %%
df1b.sort_values('Count')
# Out:
#                                         Quantity Ordered  Price Each  Month  \
# Grouped
# iPhone,iPhone                                          2     1400.00     12
# 27in 4K Gaming Monitor,Vareebadd Phone                 2      789.99      8
# ThinkPad Laptop,27in 4K Gaming Monitor                 2     1389.98     10
# Macbook Pro Laptop,Flatscreen TV                       2     2000.00     24
# Flatscreen TV,20in Monitor                             2      409.99     10
# ...                                                  ...         ...    ...
# Google Phone,Wired Headphones                        637   185432.97   4258
# Vareebadd Phone,USB-C Charging Cable                 648   128528.40   4488
# iPhone,Wired Headphones                              752   257028.39   4930
# Google Phone,USB-C Charging Cable                   1785   523829.20  11684
# iPhone,Lightning Charging Cable                     1822   630585.90  11958
#
#                                             Sales   Hour  Minute  Count
# Grouped
# iPhone,iPhone                             1400.00     46      82      2
# 27in 4K Gaming Monitor,Vareebadd Phone     789.99     24      62      2
# ThinkPad Laptop,27in 4K Gaming Monitor    1389.98     32     110      2
# Macbook Pro Laptop,Flatscreen TV          2000.00     22       2      2
# Flatscreen TV,20in Monitor                 409.99     26      22      2
# ...                                           ...    ...     ...    ...
# Google Phone,Wired Headphones           185804.66   8620   17876    606
# Vareebadd Phone,USB-C Charging Cable    128815.20   8934   17944    624
# iPhone,Wired Headphones                 257388.09  10262   20940    722
# Google Phone,USB-C Charging Cable       524701.55  24798   50354   1712
# iPhone,Lightning Charging Cable         631453.00  26110   53034   1764
#
# [366 rows x 7 columns]

# %% [markdown]
# #### What product is sold the most and why do you think it is sold the most

# %%
product_group = all_data.groupby('Product')

# %%
product_group.sum()
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\197202662.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   product_group.sum()
#                             Quantity Ordered  Price Each   Month       Sales  \
# Product
# 20in Monitor                            4129   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# 27in FHD Monitor                        7550  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                  27635    79015.68  145558   106118.40
# AAA Batteries (4-pack)                 31017    61716.59  146370    92740.83
# Apple Airpods Headphones               15661  2332350.00  109477  2349150.00
# Bose SoundSport Headphones             13457  1332366.75   94113  1345565.43
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# LG Dryer                                 646   387600.00    4383   387600.00
# LG Washing Machine                       666   399600.00    4523   399600.00
# Lightning Charging Cable               23217   323787.10  153092   347094.15
# Macbook Pro Laptop                      4728  8030800.00   33548  8037600.00
# ThinkPad Laptop                         4130  4127958.72   28950  4129958.70
# USB-C Charging Cable                   23975   261740.85  154819   286501.25
# Vareebadd Phone                         2068   826000.00   14309   827200.00
# Wired Headphones                       20557   226395.18  133397   246478.43
# iPhone                                  6849  4789400.00   47941  4794300.00
#
#                               Hour  Minute  Count
# Product
# 20in Monitor                 58764  122252   4101
# 27in 4K Gaming Monitor       90916  184331   6230
# 27in FHD Monitor            107540  219948   7507
# 34in Ultrawide Monitor       89076  183480   6181
# AA Batteries (4-pack)       298342  609039  20577
# AAA Batteries (4-pack)      297332  612113  20641
# Apple Airpods Headphones    223304  455570  15549
# Bose SoundSport Headphones  192445  392603  13325
# Flatscreen TV                68815  142789   4800
# Google Phone                 79479  162773   5525
# LG Dryer                      9326   19043    646
# LG Washing Machine            9785   19462    666
# Lightning Charging Cable    312529  634442  21658
# Macbook Pro Laptop           68261  137574   4724
# ThinkPad Laptop              59746  121508   4128
# USB-C Charging Cable        314645  647586  21903
# Vareebadd Phone              29472   61835   2065
# Wired Headphones            271720  554023  18882
# iPhone                       98657  201688   6842

# %%
quantity_ordered = product_group.sum()['Quantity Ordered']
product = [product for product,df in product_group]

plt.bar(product,quantity_ordered)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\3829128490.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   quantity_ordered = product_group.sum()['Quantity Ordered']

# %%
quantity_ordered = product_group.sum()['Sales']
product = [product for product,df in product_group]

plt.bar(product,quantity_ordered)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\1837150891.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   quantity_ordered = product_group.sum()['Sales']

# %%
prices = all_data.groupby('Product').mean()['Price Each']
prices
# Out:
# C:\Users\VISHWAS\AppData\Local\Temp\ipykernel_37244\840125450.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   prices = all_data.groupby('Product').mean()['Price Each']
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64
